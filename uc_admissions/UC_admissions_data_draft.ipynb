# %%
import pandas as pd

# %%
#"C:\Users\mtsao\Desktop\code_fun\FR_UC_Admits.csv" this doesn't work - encoding is not utf-8, and I don't know the encoding

# %%
#"C:\Users\mtsao\Desktop/code_fun/FR ENR_data.csv"

# %%
# import data

# %%
uc = pd.read_csv('C:/Users/mtsao/Desktop/code_fun/FR ENR_data.csv') # correct path, and encoded

# %%
uc.head()
# Out:
#                        Calculation1                       School         City  \
# 0  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 1  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 2  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 3  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 4  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
#
#   County/State/ Territory Category         Ethnicity  Count
# 0             Los Angeles      Enr             Asian     16
# 1             Los Angeles      Adm             Asian     30
# 2             Los Angeles      App             Asian     41
# 3             Los Angeles      Enr  Hispanic/ Latinx      6
# 4             Los Angeles      Adm  Hispanic/ Latinx     22

# %%
# clean data

# %%
uc.rename(columns={'Count' : 'Category', 'uad_uc_ethn_7_cat' : 'Ethnicity', 'Pivot Field Values' : 'Count'}, inplace=True)

# %%
Irvine = (uc['City'] == 'Irvine')

# %%
Irvine_only = uc[Irvine]

# %%
Irvine_only
# Out:
#                            Calculation1                        School    City  \
# 336   ARNOLD O BECKMAN HIGH SCHOOL51267  ARNOLD O BECKMAN HIGH SCHOOL  Irvine
# 337   ARNOLD O BECKMAN HIGH SCHOOL51267  ARNOLD O BECKMAN HIGH SCHOOL  Irvine
# 338   ARNOLD O BECKMAN HIGH SCHOOL51267  ARNOLD O BECKMAN HIGH SCHOOL  Irvine
# 339   ARNOLD O BECKMAN HIGH SCHOOL51267  ARNOLD O BECKMAN HIGH SCHOOL  Irvine
# 340   ARNOLD O BECKMAN HIGH SCHOOL51267  ARNOLD O BECKMAN HIGH SCHOOL  Irvine
# ...                                 ...                           ...     ...
# 5066        WOODBRIDGE HIGH SCHOOL51274        WOODBRIDGE HIGH SCHOOL  Irvine
# 5067        WOODBRIDGE HIGH SCHOOL51274        WOODBRIDGE HIGH SCHOOL  Irvine
# 5068        WOODBRIDGE HIGH SCHOOL51274        WOODBRIDGE HIGH SCHOOL  Irvine
# 5069        WOODBRIDGE HIGH SCHOOL51274        WOODBRIDGE HIGH SCHOOL  Irvine
# 5070        WOODBRIDGE HIGH SCHOOL51274        WOODBRIDGE HIGH SCHOOL  Irvine
#
#      County/State/ Territory Category         Ethnicity  Count
# 336                   Orange      Enr             Int'l      4
# 337                   Orange      Adm             Int'l      5
# 338                   Orange      App             Int'l      5
# 339                   Orange      Enr             White     15
# 340                   Orange      Adm             White     35
# ...                      ...      ...               ...    ...
# 5066                  Orange      Adm  African American      3
# 5067                  Orange      App  African American      8
# 5068                  Orange      Enr               All    119
# 5069                  Orange      Adm               All    211
# 5070                  Orange      App               All    318
#
# [106 rows x 7 columns]

# %%
school = uc['School']

# %%
school.head()
# Out:
# 0    ABRAHAM LINCOLN HIGH SCHOOL
# 1    ABRAHAM LINCOLN HIGH SCHOOL
# 2    ABRAHAM LINCOLN HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL
# Name: School, dtype: object

# %%
whs = (school == 'WOODBRIDGE HIGH SCHOOL')

# %%
only_whs = uc[whs]

# %%
only_whs
# Out:
#                      Calculation1                  School    City  \
# 5053  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5054  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5055  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5056  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5057  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5058  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5059  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5060  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5061  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5062  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5063  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5064  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5065  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5066  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5067  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5068  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5069  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5070  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
#
#      County/State/ Territory Category         Ethnicity  Count
# 5053                  Orange      Adm             Int'l      6
# 5054                  Orange      App             Int'l      6
# 5055                  Orange      Adm  Domestic Unknown      8
# 5056                  Orange      App  Domestic Unknown     12
# 5057                  Orange      Enr             White     22
# 5058                  Orange      Adm             White     40
# 5059                  Orange      App             White     79
# 5060                  Orange      Enr             Asian     82
# 5061                  Orange      Adm             Asian    142
# 5062                  Orange      App             Asian    189
# 5063                  Orange      Enr  Hispanic/ Latinx      7
# 5064                  Orange      Adm  Hispanic/ Latinx     12
# 5065                  Orange      App  Hispanic/ Latinx     24
# 5066                  Orange      Adm  African American      3
# 5067                  Orange      App  African American      8
# 5068                  Orange      Enr               All    119
# 5069                  Orange      Adm               All    211
# 5070                  Orange      App               All    318

# %%
totals = only_whs.groupby('Category')['Count'].sum()

# %%
totals
# Out:
# Category
# Adm    422
# App    636
# Enr    230
# Name: Count, dtype: int64

# %%
eth_totals = only_whs.groupby('Ethnicity')['Count'].sum()

# %%
eth_totals
# Out:
# Ethnicity
# African American     11
# All                 648
# Asian               413
# Domestic Unknown     20
# Hispanic/ Latinx     43
# Int'l                12
# White               141
# Name: Count, dtype: int64

# %%
admits = (only_whs['Category'] == 'Adm')

# %%
whs_admits = only_whs[admits]

# %%
whs_admits.head()
# Out:
#                      Calculation1                  School    City  \
# 5053  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5055  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5058  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5061  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5064  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
#
#      County/State/ Territory Category         Ethnicity  Count
# 5053                  Orange      Adm             Int'l      6
# 5055                  Orange      Adm  Domestic Unknown      8
# 5058                  Orange      Adm             White     40
# 5061                  Orange      Adm             Asian    142
# 5064                  Orange      Adm  Hispanic/ Latinx     12

# %%
whs_applicants = only_whs[only_whs['Category'] == 'App']

# %%
whs_applicants.head()
# Out:
#                      Calculation1                  School    City  \
# 5054  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5056  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5059  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5062  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5065  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
#
#      County/State/ Territory Category         Ethnicity  Count
# 5054                  Orange      App             Int'l      6
# 5056                  Orange      App  Domestic Unknown     12
# 5059                  Orange      App             White     79
# 5062                  Orange      App             Asian    189
# 5065                  Orange      App  Hispanic/ Latinx     24

# %%
whs_apps = whs_applicants[['Category', 'Ethnicity', 'Count']]

# %%
whs_apps
# Out:
#      Category         Ethnicity  Count
# 5054      App             Int'l      6
# 5056      App  Domestic Unknown     12
# 5059      App             White     79
# 5062      App             Asian    189
# 5065      App  Hispanic/ Latinx     24
# 5067      App  African American      8
# 5070      App               All    318

# %%
rates = pd.merge(whs_admits, whs_applicants, on=['School', 'City', 'Calculation1', 'County/State/ Territory', 'Ethnicity'])

# %%
rates
# Out:
#                   Calculation1                  School    City  \
# 0  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 1  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 2  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 3  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 4  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 6  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
#
#   County/State/ Territory Category_x         Ethnicity  Count_x Category_y  \
# 0                  Orange        Adm             Int'l        6        App
# 1                  Orange        Adm  Domestic Unknown        8        App
# 2                  Orange        Adm             White       40        App
# 3                  Orange        Adm             Asian      142        App
# 4                  Orange        Adm  Hispanic/ Latinx       12        App
# 5                  Orange        Adm  African American        3        App
# 6                  Orange        Adm               All      211        App
#
#    Count_y
# 0        6
# 1       12
# 2       79
# 3      189
# 4       24
# 5        8
# 6      318

# %%
rates_2 = pd.merge(whs_admits, whs_apps, on='Ethnicity')

# %%
rates_2
# Out:
#                   Calculation1                  School    City  \
# 0  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 1  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 2  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 3  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 4  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 5  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
# 6  WOODBRIDGE HIGH SCHOOL51274  WOODBRIDGE HIGH SCHOOL  Irvine
#
#   County/State/ Territory Category_x         Ethnicity  Count_adm Category_y  \
# 0                  Orange        Adm             Int'l          6        App
# 1                  Orange        Adm  Domestic Unknown          8        App
# 2                  Orange        Adm             White         40        App
# 3                  Orange        Adm             Asian        142        App
# 4                  Orange        Adm  Hispanic/ Latinx         12        App
# 5                  Orange        Adm  African American          3        App
# 6                  Orange        Adm               All        211        App
#
#    Count_app
# 0          6
# 1         12
# 2         79
# 3        189
# 4         24
# 5          8
# 6        318

# %%
rates_2.rename(columns={'Count_x' : 'Count_adm', 'Count_y' : 'Count_app'}, inplace=True)

# %%
rates_update = rates_2[['School', 'City', 'County/State/ Territory', 'Ethnicity', 'Count_app', 'Count_adm']]

# %%
rates_update
# Out:
#                    School    City County/State/ Territory         Ethnicity  \
# 0  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             Int'l
# 1  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  Domestic Unknown
# 2  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             White
# 3  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             Asian
# 4  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  Hispanic/ Latinx
# 5  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  African American
# 6  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange               All
#
#    Count_app  Count_adm
# 0          6          6
# 1         12          8
# 2         79         40
# 3        189        142
# 4         24         12
# 5          8          3
# 6        318        211

# %%
rates_update['admit_rate'] = (rates_update['Count_adm']/rates_update['Count_app'])

# %%
rates_update.drop(['new'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22052\1824920020.py in <module>
# ----> 1 rates_update.drop(['new'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['new'] not found in axis"

# %%
rates_update['admit_rate'] = (rates_update['Count_adm']/rates_update['Count_app'])*100
# Out:
# C:\Users\mtsao\AppData\Local\Temp\ipykernel_22052\126104074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rates_update['admit_rate'] = (rates_update['Count_adm']/rates_update['Count_app'])*100

# %%
rates_update
# Out:
#                    School    City County/State/ Territory         Ethnicity  \
# 0  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             Int'l
# 1  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  Domestic Unknown
# 2  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             White
# 3  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange             Asian
# 4  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  Hispanic/ Latinx
# 5  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange  African American
# 6  WOODBRIDGE HIGH SCHOOL  Irvine                  Orange               All
#
#    Count_app  Count_adm  admit_rate
# 0          6          6  100.000000
# 1         12          8   66.666667
# 2         79         40   50.632911
# 3        189        142   75.132275
# 4         24         12   50.000000
# 5          8          3   37.500000
# 6        318        211   66.352201

# %%
# part two: repeat but for all of LA, OC, and SD counties

# %%
uc.head()
# Out:
#                        Calculation1                       School         City  \
# 0  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 1  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 2  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 3  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
# 4  ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL  Los Angeles
#
#   County/State/ Territory Category         Ethnicity  Count
# 0             Los Angeles      Enr             Asian     16
# 1             Los Angeles      Adm             Asian     30
# 2             Los Angeles      App             Asian     41
# 3             Los Angeles      Enr  Hispanic/ Latinx      6
# 4             Los Angeles      Adm  Hispanic/ Latinx     22

# %%
uc_admits = uc[uc['Category'] == 'Adm']

# %%
uc_apps = uc[uc['Category'] == 'App']

# %%
uc_apps
# Out:
#                              Calculation1                          School  \
# 2        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 5        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 8        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 11    ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
# 14    ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
# ...                                   ...                             ...
# 5105         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 5108         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 5111         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 5114         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 5117         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
#
#              City County/State/ Territory Category         Ethnicity  Count
# 2     Los Angeles             Los Angeles      App             Asian     41
# 5     Los Angeles             Los Angeles      App  Hispanic/ Latinx     40
# 8     Los Angeles             Los Angeles      App               All     83
# 11    Los Angeles             Los Angeles      App  Hispanic/ Latinx     19
# 14    Los Angeles             Los Angeles      App               All     20
# ...           ...                     ...      ...               ...    ...
# 5105  Yorba Linda                  Orange      App  Domestic Unknown     15
# 5108  Yorba Linda                  Orange      App             White     40
# 5111  Yorba Linda                  Orange      App             Asian     90
# 5114  Yorba Linda                  Orange      App  Hispanic/ Latinx     27
# 5117  Yorba Linda                  Orange      App               All    177
#
# [1856 rows x 7 columns]

# %%
merged_uc = pd.merge(uc_admits, uc_apps, on=['Calculation1', 'School', 'City', 'County/State/ Territory', 'Ethnicity'])

# %%
merged_uc.head()
# Out:
#                           Calculation1                          School  \
# 0     ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 1     ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 2     ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 3  ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
# 4  ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
#
#           City County/State/ Territory Category_x         Ethnicity  Count_x  \
# 0  Los Angeles             Los Angeles        Adm             Asian       30
# 1  Los Angeles             Los Angeles        Adm  Hispanic/ Latinx       22
# 2  Los Angeles             Los Angeles        Adm               All       53
# 3  Los Angeles             Los Angeles        Adm  Hispanic/ Latinx       13
# 4  Los Angeles             Los Angeles        Adm               All       14
#
#   Category_y  Count_y
# 0        App       41
# 1        App       40
# 2        App       83
# 3        App       19
# 4        App       20

# %%
merged_uc.rename(columns={'Count_x' : 'Count_adm', 'Count_y' : 'Count_app'}, inplace=True)

# %%
merged_uc.drop(['Category_x', 'Category_y'], axis=1, inplace=True)

# %%
merged_uc['admit_rate'] = (merged_uc['Count_adm'] / merged_uc['Count_app'])*100

# %%
merged_uc
# Out:
#                              Calculation1                          School  \
# 0        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 1        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 2        ABRAHAM LINCOLN HIGH SCHOOL51520     ABRAHAM LINCOLN HIGH SCHOOL
# 3     ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
# 4     ACADEMIA AVANCE CHARTER SCHOOL54247  ACADEMIA AVANCE CHARTER SCHOOL
# ...                                   ...                             ...
# 1770         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 1771         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 1772         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 1773         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
# 1774         YORBA LINDA HIGH SCHOOL54321         YORBA LINDA HIGH SCHOOL
#
#              City County/State/ Territory         Ethnicity  Count_adm  \
# 0     Los Angeles             Los Angeles             Asian         30
# 1     Los Angeles             Los Angeles  Hispanic/ Latinx         22
# 2     Los Angeles             Los Angeles               All         53
# 3     Los Angeles             Los Angeles  Hispanic/ Latinx         13
# 4     Los Angeles             Los Angeles               All         14
# ...           ...                     ...               ...        ...
# 1770  Yorba Linda                  Orange  Domestic Unknown          6
# 1771  Yorba Linda                  Orange             White         16
# 1772  Yorba Linda                  Orange             Asian         71
# 1773  Yorba Linda                  Orange  Hispanic/ Latinx         11
# 1774  Yorba Linda                  Orange               All        108
#
#       Count_app  admit_rate
# 0            41   73.170732
# 1            40   55.000000
# 2            83   63.855422
# 3            19   68.421053
# 4            20   70.000000
# ...         ...         ...
# 1770         15   40.000000
# 1771         40   40.000000
# 1772         90   78.888889
# 1773         27   40.740741
# 1774        177   61.016949
#
# [1775 rows x 8 columns]

# %%
merged_uc.to_csv('C:/Users/mtsao/Desktop/code_fun/merged_uc.csv')

# %%
merged_uc[(merged_uc['School'] == 'MARK KEPPEL HIGH SCHOOL') | (merged_uc['School'] == 'WOODBRIDGE HIGH SCHOOL')]
# Out:
#                       Calculation1                   School      City  \
# 995   MARK KEPPEL HIGH SCHOOL50055  MARK KEPPEL HIGH SCHOOL  Alhambra
# 996   MARK KEPPEL HIGH SCHOOL50055  MARK KEPPEL HIGH SCHOOL  Alhambra
# 997   MARK KEPPEL HIGH SCHOOL50055  MARK KEPPEL HIGH SCHOOL  Alhambra
# 1752   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1753   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1754   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1755   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1756   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1757   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
# 1758   WOODBRIDGE HIGH SCHOOL51274   WOODBRIDGE HIGH SCHOOL    Irvine
#
#      County/State/ Territory         Ethnicity  Count_adm  Count_app  \
# 995              Los Angeles             Asian        158        247
# 996              Los Angeles  Hispanic/ Latinx          9         20
# 997              Los Angeles               All        172        275
# 1752                  Orange             Int'l          6          6
# 1753                  Orange  Domestic Unknown          8         12
# 1754                  Orange             White         40         79
# 1755                  Orange             Asian        142        189
# 1756                  Orange  Hispanic/ Latinx         12         24
# 1757                  Orange  African American          3          8
# 1758                  Orange               All        211        318
#
#       admit_rate
# 995    63.967611
# 996    45.000000
# 997    62.545455
# 1752  100.000000
# 1753   66.666667
# 1754   50.632911
# 1755   75.132275
# 1756   50.000000
# 1757   37.500000
# 1758   66.352201

# %%
merged_uc.groupby('Ethnicity')['admit_rate'].mean()
# Out:
# Ethnicity
# African American    59.516697
# All                 64.575007
# American Indian     60.000000
# Asian               72.007852
# Domestic Unknown    68.237729
# Hispanic/ Latinx    60.918722
# Int'l               83.256975
# White               60.262946
# Name: admit_rate, dtype: float64

# %%
x = merged_uc.groupby('Ethnicity')['Count_app'].sum()

# %%
y = merged_uc.groupby('Ethnicity')['Count_adm'].sum()

# %%
overall_admit_ethn = pd.merge(x, y, on='Ethnicity')

# %%
overall_admit_ethn
# Out:
#                   Count_app  Count_adm
# Ethnicity
# African American       2613       1497
# All                   53676      34265
# American Indian           5          3
# Asian                 15210      10923
# Domestic Unknown        382        261
# Hispanic/ Latinx      22333      13807
# Int'l                   133        108
# White                  9087       5102

# %%
overall_admit_ethn['admit_rate'] = (overall_admit_ethn['Count_adm'] / overall_admit_ethn['Count_app'])*100

# %%
overall_admit_ethn # for LA, SD, Orange counties
# Out:
#                   Count_app  Count_adm  admit_rate
# Ethnicity
# African American       2613       1497   57.290471
# All                   53676      34265   63.836724
# American Indian           5          3   60.000000
# Asian                 15210      10923   71.814596
# Domestic Unknown        382        261   68.324607
# Hispanic/ Latinx      22333      13807   61.823311
# Int'l                   133        108   81.203008
# White                  9087       5102   56.146143

# %%
overall_admit_ethn.to_csv('C:/Users/mtsao/Desktop/code_fun/overall_uc_admits_by_ethnicity_la_oc_sd.csv')
